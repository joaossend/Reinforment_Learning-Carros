# %%
# !python newcar.py
# Out:
# pygame 2.1.2 (SDL 2.0.18, Python 3.8.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html
#
#  ****** Running generation 0 ******
#
# Population's average fitness: 211.64222 stdev: 311.23806
# Best fitness: 1011.33333 - size: (4, 20) - species 1 - id 20
# Average adjusted fitness: 0.206
# Mean genetic distance 1.202, standard deviation 0.219
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    0    30   1011.3    0.206     0
# Total extinctions: 0
# Generation time: 1.863 sec
#
#  ****** Running generation 1 ******
#
# Population's average fitness: 659.82444 stdev: 555.18204
# Best fitness: 1965.20000 - size: (4, 19) - species 1 - id 56
# Average adjusted fitness: 0.333
# Mean genetic distance 1.185, standard deviation 0.238
# Population of 30 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
# ...

# %%
# https://www.youtube.com/watch?v=2o-jMhXmmxA

# %%
aaaaasdasdasdasdasdas

# %% [markdown]
# # Cria a população inicial
# population = neat.Population(config)
#
# # Adiciona repórteres para monitorar o progresso
# population.add_reporter(neat.StdOutReporter(True))
# stats = neat.StatisticsReporter()
# population.add_reporter(stats)
#
# # Executa a avaliação da população por 10 gerações
# winner = population.run(eval_genomes, 10)
